# %%
###Questions:
#Is there a discernible difference in the frequency or location of wildfires across the time gap we are looking at?
#Can we relate the location and causes of the wildfires to known changes in city population?
#What can we predict about the future locations or frequency of wildfires across the US?

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/riora/Documents/A+Documents/UBC/Summer21/DATA301/Project/Data/firesNEW.csv", encoding = 'ISO-8859-1', low_memory=False)
#len(original_df)
df.head()
# Out:
#    FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM NWCG_REPORTING_AGENCY  \
# 0       1  FS-1418826                FED   FS-FIRESTAT                    FS
# 1       2  FS-1418827                FED   FS-FIRESTAT                    FS
# 2       3  FS-1418835                FED   FS-FIRESTAT                    FS
# 3       4  FS-1418845                FED   FS-FIRESTAT                    FS
# 4       5  FS-1418847                FED   FS-FIRESTAT                    FS
#
#   NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 0                USCAPNF    Plumas National Forest                  0511
# 1                USCAENF  Eldorado National Forest                  0503
# 2                USCAENF  Eldorado National Forest                  0503
# 3                USCAENF  Eldorado National Forest                  0503
# 4                USCAENF  Eldorado National Forest                  0503
#
# ...

# %%
df.drop(columns=['NWCG_REPORTING_UNIT_NAME', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM', 'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID', 'SOURCE_REPORTING_UNIT', 'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID', 'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'ICS_209_PLUS_INCIDENT_JOIN_ID', 'ICS_209_PLUS_COMPLEX_JOIN_ID', 'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME', 'DISCOVERY_DOY', 'NWCG_CAUSE_AGE_CATEGORY', 'OWNER_DESCR', 'COUNTY', 'NWCG_GENERAL_CAUSE'], inplace=True)
df.rename(columns = {'NWCG_CAUSE_CLASSIFICATION':'CAUSE'}, inplace = True)
df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_YEAR     DISCOVERY_DATE  DISCOVERY_TIME    CAUSE  \
# 0       1  FOUNTAIN       2005   2005-2-2 0:00:00          1300.0    Human
# 1       2    PIGEON       2004  2004-5-12 0:00:00           845.0  Natural
# 2       3     SLACK       2004  2004-5-31 0:00:00          1921.0    Human
# 3       4      DEER       2004  2004-6-28 0:00:00          1600.0  Natural
# 4       5  STEVENOT       2004  2004-6-28 0:00:00          1600.0  Natural
#
#            CONT_DATE  CONT_DOY  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  \
# 0   2005-2-2 0:00:00      33.0     1730.0       0.10               A
# 1  2004-5-12 0:00:00     133.0     1530.0       0.25               A
# 2  2004-5-31 0:00:00     152.0     2024.0       0.10               A
# 3   2004-7-3 0:00:00     185.0     1400.0       0.10               A
# 4   2004-7-3 0:00:00     185.0     1200.0       0.10               A
#
#     LATITUDE   LONGITUDE STATE  FIPS_CODE         FIPS_NAME
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#             FOD_ID                    FIRE_NAME  FIRE_YEAR  \
# 0                1                     FOUNTAIN       2005
# 1                2                       PIGEON       2004
# 2                3                        SLACK       2004
# 3                4                         DEER       2004
# 4                5                     STEVENOT       2004
# ...            ...                          ...        ...
# 2166694  400481851        TURNPIKE RD/BALAZS RD       2018
# 2166695  400481852             21 PLYMOUTH ROAD       2018
# 2166696  400481854          257 STAGECOACH ROAD       2018
# 2166697  400481855  KINGS HWY AND GOOSE HILL RD       2018
# 2166698  400481857                36 GREEN LANE       2018
#
#              DISCOVERY_DATE  DISCOVERY_TIME    CAUSE           CONT_DATE  \
# 0          2005-2-2 0:00:00          1300.0    Human    2005-2-2 0:00:00
# 1         2004-5-12 0:00:00           845.0  Natural   2004-5-12 0:00:00
# ...

# %%
#According to https://www.nwcg.gov/term/glossary/size-class-of-fire, fire classes of less than 10 acres are classes A,B. These will not be counted due to our aim to only consider considerable fires.
df.drop(df[(df['FIRE_SIZE_CLASS']=='A')].index, inplace=True)
df.drop(df[(df['FIRE_SIZE_CLASS']=='B')].index, inplace=True)
df.reset_index(inplace=True)
df
# Out:
#          index     FOD_ID     FIRE_NAME  FIRE_YEAR      DISCOVERY_DATE  \
# 0           16         17         POWER       2004   2004-10-6 0:00:00
# 1           17         18         FREDS       2004  2004-10-13 0:00:00
# 2           25         26      BACHELOR       2004   2004-7-20 0:00:00
# 3           37         38    HOWARD GAP       2005   2005-1-27 0:00:00
# 4           39         40  AUSTIN CREEK       2005   2005-2-12 0:00:00
# ...        ...        ...           ...        ...                 ...
# 83570  2165253  400480175         10365       2018  2018-11-14 0:00:00
# 83571  2165558  400480523          1847       2018   2018-2-17 0:00:00
# 83572  2165563  400480528           130       2018    2018-6-4 0:00:00
# 83573  2166438  400481557        271409       2018   2018-7-24 0:00:00
# 83574  2166585  400481725            96       2018   2018-5-23 0:00:00
#
#        DISCOVERY_TIME    CAUSE           CONT_DATE  CONT_DOY  CONT_TIME  \
# ...

# %%
def load_and_process(file_path):

    #Chain 1: Loading Data, removing unnecessary columns, and renaming necessary columns.
    df1 = (
        pd.read_csv(file_path, encoding = 'ISO-8859-1', low_memory=False)
        .drop(columns=['NWCG_REPORTING_UNIT_NAME', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM', 'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID', 'SOURCE_REPORTING_UNIT', 'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID', 'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'ICS_209_PLUS_INCIDENT_JOIN_ID', 'ICS_209_PLUS_COMPLEX_JOIN_ID', 'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME', 'DISCOVERY_DOY', 'NWCG_CAUSE_AGE_CATEGORY', 'OWNER_DESCR', 'COUNTY', 'NWCG_GENERAL_CAUSE'])
        .rename(columns = {'NWCG_CAUSE_CLASSIFICATION':'CAUSE'})
        .dropna()
    )
    
    df2 = df1
    
    #Chain 2: Dropping unnecessary rows, and resetting the index to aid in analysis.
    df2 = (
        df2.drop(df2[(df2['FIRE_SIZE_CLASS']=='A')].index)
        .drop(df2[(df2['FIRE_SIZE_CLASS']=='B')].index)
        .reset_index()
        
    )

    dflatest=df2
    return dflatest

# %%
#load_and_process("C:/Users/riora/Documents/A+Documents/UBC/Summer21/DATA301/Project/Data/firesNEW.csv")
