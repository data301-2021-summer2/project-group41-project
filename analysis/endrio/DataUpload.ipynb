# %%
#ran pip install pyodbc in Terminal

import pandas as pd
import pyodbc

#conn = pyodbc.connect(r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};UID=admin;UserCommitSync=Yes;Threads=3;SafeTransactions=0;PageTimeout=5;MaxScanRows=8;MaxBufferSize=2048;FIL=MS Access;DriverId=25;DefaultDir=C:\Users\riora\Documents\A+Documents\UBC\Summer21\DATA301\Project\RawDataDownload\Data;DBQ=C:\Users\riora\Documents\A+Documents\UBC\Summer21\DATA301\Project\RawDataDownload\Data\FPA_FOD_20210617.accdb;')
#cursor = conn.cursor()
#cursor.execute('select * from Fires')
   
#for row in cursor.fetchall():
#   print (row)
#cursor.close()
#cursor_pendings.close
#conn.close()

# %%
df = pd.read_csv("C:/Users/riora/Desktop/Fires2.csv", encoding = 'ISO-8859-1', low_memory=False)
#len(df)
df.head()
# Out:
#    1  FS-1418826  FED  FS-FIRESTAT  FS  USCAPNF    Plumas National Forest  \
# 0  2  FS-1418827  FED  FS-FIRESTAT  FS  USCAENF  Eldorado National Forest
# 1  3  FS-1418835  FED  FS-FIRESTAT  FS  USCAENF  Eldorado National Forest
# 2  4  FS-1418845  FED  FS-FIRESTAT  FS  USCAENF  Eldorado National Forest
# 3  5  FS-1418847  FED  FS-FIRESTAT  FS  USCAENF  Eldorado National Forest
# 4  6  FS-1418849  FED  FS-FIRESTAT  FS  USCAENF  Eldorado National Forest
#
#    0511  Plumas National Forest.1 1.1  ...    1730  0.10  A 40.03694444  \
# 0  0503  Eldorado National Forest  13  ...  1530.0  0.25  A   38.933056
# 1  0503  Eldorado National Forest  27  ...  2024.0  0.10  A   38.984167
# 2  0503  Eldorado National Forest  43  ...  1400.0  0.10  A   38.559167
# 3  0503  Eldorado National Forest  44  ...  1200.0  0.10  A   38.559167
# 4  0503  Eldorado National Forest  54  ...  1600.0  0.10  A   38.635278
#
#   -121.00583333              USFS  CA  63   06063     Plumas County
# 0   -120.404444              USFS  CA  61  6061.0     Placer County
# 1   -120.735556  STATE OR PRIVATE  CA  17  6017.0  El Dorado County
# 2   -119.913333              USFS  CA   3  6003.0     Alpine County
# 3   -119.933056              USFS  CA   3  6003.0     Alpine County
# 4   -120.103611              USFS  CA   5  6005.0     Amador County
#
# [5 rows x 37 columns]
