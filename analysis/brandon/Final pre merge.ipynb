# %%
import sys

sys.path.append('..')
from scripts.project_functions import load_and_process_brandon as lnp
lnp('https://media.githubusercontent.com/media/data301-2021-summer2/project-group41-project/main/data/processed/FiresNEW.csv?token=AUXSV2TOJZ7PZNSSIGAUJT3BA4WFC','https://raw.githubusercontent.com/data301-2021-summer2/project-group41-project/main/data/processed/csvData.csv?token=AI4GJYGVTJDXLG42EJ4W4PTBA4OTQ','https://raw.githubusercontent.com/data301-2021-summer2/project-group41-project/main/data/processed/tavg.csv?token=AI4GJYAVBA3IMRDKK6JJAN3BA4OVY')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7136/1795271031.py in <module>
#       3 sys.path.append('..')
#       4 from scripts.project_functions import load_and_process_brandon as lnp
# ----> 5 lnp('https://media.githubusercontent.com/media/data301-2021-summer2/project-group41-project/main/data/processed/FiresNEW.csv?token=AUXSV2TOJZ7PZNSSIGAUJT3BA4WFC','https://raw.githubusercontent.com/data301-2021-summer2/project-group41-project/main/data/processed/csvData.csv?token=AI4GJYGVTJDXLG42EJ4W4PTBA4OTQ','https://raw.githubusercontent.com/data301-2021-summer2/project-group41-project/main/data/processed/tavg.csv?token=AI4GJYAVBA3IMRDKK6JJAN3BA4OVY')
#
# ~\Desktop\DATA 301\Project\project-group41-project\analysis\scripts\project_functions.py in load_and_process_brandon(filepath1, filepath2, filepath3)
# ...

# %%
dffinal.head()
