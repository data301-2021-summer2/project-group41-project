# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfraw = pd.read_csv("C:/Users/Don/Desktop/DATA 301/Project/FiresNEW.csv", encoding = 'ISO-8859-1', low_memory=False)
dfraw
# Out:
#             FOD_ID               FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0                1           FS-1418826                FED   FS-FIRESTAT
# 1                2           FS-1418827                FED   FS-FIRESTAT
# 2                3           FS-1418835                FED   FS-FIRESTAT
# 3                4           FS-1418845                FED   FS-FIRESTAT
# 4                5           FS-1418847                FED   FS-FIRESTAT
# ...            ...                  ...                ...           ...
# 2166748  400482078  ICS209_2016_4363266          INTERAGCY     IA-ICS209
# 2166749  400482080  ICS209_2016_4433939          INTERAGCY     IA-ICS209
# 2166750  400482083  ICS209_2017_7335143          INTERAGCY     IA-ICS209
# 2166751  400482085  ICS209_2017_7186124          INTERAGCY     IA-ICS209
# 2166752  400482086  ICS209_2015_2836014          INTERAGCY     IA-ICS209
#
#         NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 0                          FS                USCAPNF
# 1                          FS                USCAENF
# 2                          FS                USCAENF
# 3                          FS                USCAENF
# 4                          FS                USCAENF
# ...                       ...                    ...
# 2166748                ST/C&L                USTNTNS
# 2166749                ST/C&L                USALALS
# 2166750                ST/C&L                USALALS
# 2166751                    FS                USAROUF
# 2166752                ST/C&L                USOKOKS
#
#                NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 0                Plumas National Forest                  0511
# 1              Eldorado National Forest                  0503
# 2              Eldorado National Forest                  0503
# 3              Eldorado National Forest                  0503
# 4              Eldorado National Forest                  0503
# ...                                 ...                   ...
# 2166748  Tennessee Division of Forestry                 TNTNS
# 2166749     Alabama Forestry Commission                 ALALS
# 2166750     Alabama Forestry Commission                 ALALS
# 2166751        Ouachita National Forest                 AROUF
# 2166752   Oklahoma Division of Forestry                 OKECU
#
#                 SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID  ...  \
# 0                   Plumas National Forest                    1  ...
# 1                 Eldorado National Forest                   13  ...
# 2                 Eldorado National Forest                   27  ...
# 3                 Eldorado National Forest                   43  ...
# 4                 Eldorado National Forest                   44  ...
# ...                                    ...                  ...  ...
# 2166748     Tennessee Division of Forestry                  NaN  ...
# 2166749        Alabama Forestry Commission                  NaN  ...
# 2166750        Alabama Forestry Commission                  NaN  ...
# 2166751           Ouachita National Forest                  NaN  ...
# 2166752  East Central Area Dispatch Office                  NaN  ...
#
#         CONT_TIME FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 0          1730.0      0.10               A  40.036944 -121.005833
# 1          1530.0      0.25               A  38.933056 -120.404444
# 2          2024.0      0.10               A  38.984167 -120.735556
# 3          1400.0      0.10               A  38.559167 -119.913333
# 4          1200.0      0.10               A  38.559167 -119.933056
# ...           ...       ...             ...        ...         ...
# 2166748       NaN    125.00               D  36.431667  -84.421667
# 2166749       NaN    120.00               D  31.143611  -88.111944
# 2166750       NaN    120.00               D  33.920000  -85.310000
# 2166751       NaN    110.00               D  34.640000  -93.400000
# 2166752       NaN    109.00               D  34.794167  -94.958000
#
#               OWNER_DESCR STATE      COUNTY  FIPS_CODE          FIPS_NAME
# 0                    USFS    CA          63     6063.0      Plumas County
# 1                    USFS    CA          61     6061.0      Placer County
# 2        STATE OR PRIVATE    CA          17     6017.0   El Dorado County
# 3                    USFS    CA           3     6003.0      Alpine County
# 4                    USFS    CA           3     6003.0      Alpine County
# ...                   ...   ...         ...        ...                ...
# 2166748           PRIVATE    TN       Scott    47151.0       Scott County
# 2166749           PRIVATE    AL  Washington     1129.0  Washington County
# 2166750           PRIVATE    AL    Cleburne     1029.0    Cleburne County
# 2166751              USFS    AR     Garland     5051.0     Garland County
# 2166752  STATE OR PRIVATE    OK    Le Flore    40079.0    Le Flore County
#
# [2166753 rows x 37 columns]

# %%
df1 = dfraw.drop(columns=["FOD_ID","FPA_ID","SOURCE_SYSTEM_TYPE","SOURCE_SYSTEM","NWCG_REPORTING_AGENCY","NWCG_REPORTING_UNIT_ID","NWCG_REPORTING_UNIT_NAME","SOURCE_REPORTING_UNIT","SOURCE_REPORTING_UNIT_NAME","LOCAL_FIRE_REPORT_ID","LOCAL_INCIDENT_ID","FIRE_CODE","FIRE_NAME","ICS_209_PLUS_INCIDENT_JOIN_ID","ICS_209_PLUS_COMPLEX_JOIN_ID","MTBS_ID","MTBS_FIRE_NAME","COMPLEX_NAME","DISCOVERY_DATE","DISCOVERY_DOY","DISCOVERY_TIME","NWCG_GENERAL_CAUSE","NWCG_CAUSE_AGE_CATEGORY","CONT_DATE","CONT_DOY","CONT_TIME","LATITUDE","LONGITUDE","OWNER_DESCR","COUNTY","FIPS_CODE","FIPS_NAME"])
df1
# Out:
#          FIRE_YEAR NWCG_CAUSE_CLASSIFICATION  FIRE_SIZE FIRE_SIZE_CLASS STATE
# 0             2005                     Human       0.10               A    CA
# 1             2004                   Natural       0.25               A    CA
# 2             2004                     Human       0.10               A    CA
# 3             2004                   Natural       0.10               A    CA
# 4             2004                   Natural       0.10               A    CA
# ...            ...                       ...        ...             ...   ...
# 2166748       2016                     Human     125.00               D    TN
# 2166749       2016                     Human     120.00               D    AL
# 2166750       2017                     Human     120.00               D    AL
# 2166751       2017                     Human     110.00               D    AR
# 2166752       2015                     Human     109.00               D    OK
#
# [2166753 rows x 5 columns]

# %%
df1 = df1.drop(df1[df1.NWCG_CAUSE_CLASSIFICATION == 'Human'].index)
df1
# Out:
#          FIRE_YEAR                NWCG_CAUSE_CLASSIFICATION  FIRE_SIZE  \
# 1             2004                                  Natural       0.25
# 3             2004                                  Natural       0.10
# 4             2004                                  Natural       0.10
# 5             2004                                  Natural       0.10
# 6             2004                                  Natural       0.10
# ...            ...                                      ...        ...
# 2166737       2016  Missing data/not specified/undetermined     176.00
# 2166738       2017  Missing data/not specified/undetermined     175.00
# 2166742       2014  Missing data/not specified/undetermined     150.00
# 2166743       2016  Missing data/not specified/undetermined     150.00
# 2166745       2017  Missing data/not specified/undetermined     150.00
#
#         FIRE_SIZE_CLASS STATE
# 1                     A    CA
# 3                     A    CA
# 4                     A    CA
# 5                     A    CA
# 6                     A    CA
# ...                 ...   ...
# 2166737               D    AR
# 2166738               D    WA
# 2166742               D    CA
# 2166743               D    AZ
# 2166745               D    OK
#
# [486695 rows x 5 columns]

# %%
df1 = df1.drop(df1[df1.NWCG_CAUSE_CLASSIFICATION == 'Missing data/not specified/undetermined'].index)
df1
# Out:
#          FIRE_YEAR NWCG_CAUSE_CLASSIFICATION  FIRE_SIZE FIRE_SIZE_CLASS STATE
# 1             2004                   Natural       0.25               A    CA
# 3             2004                   Natural       0.10               A    CA
# 4             2004                   Natural       0.10               A    CA
# 5             2004                   Natural       0.10               A    CA
# 6             2004                   Natural       0.10               A    CA
# ...            ...                       ...        ...             ...   ...
# 2166705       2017                       NaN    1200.00               F    KS
# 2166706       2017                   Natural    1200.00               F    NM
# 2166724       2016                   Natural     441.00               E    AR
# 2166725       2016                   Natural     427.00               E    MT
# 2166726       2017                   Natural     415.00               E    CO
#
# [312808 rows x 5 columns]

# %%
df1 = df1.dropna()

# %%
df1 = df1.drop(df1[df1.FIRE_SIZE_CLASS == 'A'].index)
df1
# Out:
#          FIRE_YEAR NWCG_CAUSE_CLASSIFICATION  FIRE_SIZE FIRE_SIZE_CLASS STATE
# 24            2004                   Natural        2.5               B    NM
# 25            2004                   Natural       10.0               C    NM
# 47            2005                   Natural        0.5               B    CO
# 54            2005                   Natural        0.3               B    WA
# 56            2005                   Natural        2.0               B    OR
# ...            ...                       ...        ...             ...   ...
# 2166704       2016                   Natural     1200.0               F    FL
# 2166706       2017                   Natural     1200.0               F    NM
# 2166724       2016                   Natural      441.0               E    AR
# 2166725       2016                   Natural      427.0               E    MT
# 2166726       2017                   Natural      415.0               E    CO
#
# [142217 rows x 5 columns]

# %%
df1 = df1.drop(columns=['NWCG_CAUSE_CLASSIFICATION'])
df1
# Out:
#          FIRE_YEAR  FIRE_SIZE FIRE_SIZE_CLASS STATE
# 24            2004        2.5               B    NM
# 25            2004       10.0               C    NM
# 47            2005        0.5               B    CO
# 54            2005        0.3               B    WA
# 56            2005        2.0               B    OR
# ...            ...        ...             ...   ...
# 2166704       2016     1200.0               F    FL
# 2166706       2017     1200.0               F    NM
# 2166724       2016      441.0               E    AR
# 2166725       2016      427.0               E    MT
# 2166726       2017      415.0               E    CO
#
# [142217 rows x 4 columns]

# %%
dfstate = pd.read_csv("C:/Users/Don/Desktop/DATA 301/Project/csvData.csv")
dfstate = dfstate.drop(columns='Abbrev')
dfstate = dfstate.rename(columns={'Code':'STATE'})
dfstate
# Out:
#                    State STATE
# 0                Alabama    AL
# 1                 Alaska    AK
# 2                Arizona    AZ
# 3               Arkansas    AR
# 4             California    CA
# 5               Colorado    CO
# 6            Connecticut    CT
# 7               Delaware    DE
# 8   District of Columbia    DC
# 9                Florida    FL
# 10               Georgia    GA
# 11                Hawaii    HI
# 12                 Idaho    ID
# 13              Illinois    IL
# 14               Indiana    IN
# 15                  Iowa    IA
# 16                Kansas    KS
# 17              Kentucky    KY
# 18             Louisiana    LA
# 19                 Maine    ME
# 20              Maryland    MD
# 21         Massachusetts    MA
# 22              Michigan    MI
# 23             Minnesota    MN
# 24           Mississippi    MS
# 25              Missouri    MO
# 26               Montana    MT
# 27              Nebraska    NE
# 28                Nevada    NV
# 29         New Hampshire    NH
# 30            New Jersey    NJ
# 31            New Mexico    NM
# 32              New York    NY
# 33        North Carolina    NC
# 34          North Dakota    ND
# 35                  Ohio    OH
# 36              Oklahoma    OK
# 37                Oregon    OR
# 38          Pennsylvania    PA
# 39          Rhode Island    RI
# 40        South Carolina    SC
# 41          South Dakota    SD
# 42             Tennessee    TN
# 43                 Texas    TX
# 44                  Utah    UT
# 45               Vermont    VT
# 46              Virginia    VA
# 47            Washington    WA
# 48         West Virginia    WV
# 49             Wisconsin    WI
# 50               Wyoming    WY

# %%
df2 = df1.set_index('STATE').combine_first(dfstate.set_index('STATE'))
df2.reset_index(inplace=True)
df2 = df2.drop(columns='STATE')
df2 = df2.dropna()
df2['FIRE_YEAR'] = df2['FIRE_YEAR'].astype(int)
df2 = df2.rename(columns={'FIRE_YEAR':'Date','State':'Location'})
df2
# Out:
#         FIRE_SIZE FIRE_SIZE_CLASS  Date Location
# 0            10.0               C  2009   Alaska
# 1             1.0               B  1993   Alaska
# 2             1.0               B  1993   Alaska
# 3             0.5               B  1997   Alaska
# 4             4.0               B  1999   Alaska
# ...           ...             ...   ...      ...
# 142214      500.0               E  2018  Wyoming
# 142215        4.0               B  2018  Wyoming
# 142216      100.0               D  2018  Wyoming
# 142217        1.0               B  2018  Wyoming
# 142218        1.0               B  2018  Wyoming
#
# [142215 rows x 4 columns]

# %%
##################################

# %%
dftemp=pd.read_csv("C:/Users/Don/Desktop/DATA 301/Project/tavg.csv")
dftemp
# Out:
#         Location ID                       Location    Date  Value  Rank  \
# 0               101  Alabama CD 1. Northern Valley  189501   37.7    36
# 1               101  Alabama CD 1. Northern Valley  189502   32.8     3
# 2               101  Alabama CD 1. Northern Valley  189503   50.3    53
# 3               101  Alabama CD 1. Northern Valley  189504   61.2    88
# 4               101  Alabama CD 1. Northern Valley  189505   66.8    42
# ...             ...                            ...     ...    ...   ...
# 522187         4810    Wyoming CD 10. Upper Platte  202102   18.5    30
# 522188         4810    Wyoming CD 10. Upper Platte  202103   30.9    85
# 522189         4810    Wyoming CD 10. Upper Platte  202104   37.0    51
# 522190         4810    Wyoming CD 10. Upper Platte  202105   48.3    70
# 522191         4810    Wyoming CD 10. Upper Platte  202106   63.9   126
#
#         Anomaly (1901-2000 base period)  1901-2000 Mean
# 0                                  -2.4            40.1
# 1                                 -10.3            43.1
# 2                                  -0.6            50.9
# 3                                   1.4            59.8
# 4                                  -1.2            68.0
# ...                                 ...             ...
# 522187                             -3.2            21.7
# 522188                              2.9            28.0
# 522189                             -0.5            37.5
# 522190                              0.9            47.4
# 522191                              6.8            57.1
#
# [522192 rows x 7 columns]

# %%
f = lambda dftemp : dftemp['Location'].split("CD")
dftemp['Location'] = dftemp.apply(f, axis=1)
dftemp
# Out:
#         Location ID                         Location    Date  Value  Rank  \
# 0               101  [Alabama ,  1. Northern Valley]  189501   37.7    36
# 1               101  [Alabama ,  1. Northern Valley]  189502   32.8     3
# 2               101  [Alabama ,  1. Northern Valley]  189503   50.3    53
# 3               101  [Alabama ,  1. Northern Valley]  189504   61.2    88
# 4               101  [Alabama ,  1. Northern Valley]  189505   66.8    42
# ...             ...                              ...     ...    ...   ...
# 522187         4810    [Wyoming ,  10. Upper Platte]  202102   18.5    30
# 522188         4810    [Wyoming ,  10. Upper Platte]  202103   30.9    85
# 522189         4810    [Wyoming ,  10. Upper Platte]  202104   37.0    51
# 522190         4810    [Wyoming ,  10. Upper Platte]  202105   48.3    70
# 522191         4810    [Wyoming ,  10. Upper Platte]  202106   63.9   126
#
#         Anomaly (1901-2000 base period)  1901-2000 Mean
# 0                                  -2.4            40.1
# 1                                 -10.3            43.1
# 2                                  -0.6            50.9
# 3                                   1.4            59.8
# 4                                  -1.2            68.0
# ...                                 ...             ...
# 522187                             -3.2            21.7
# 522188                              2.9            28.0
# 522189                             -0.5            37.5
# 522190                              0.9            47.4
# 522191                              6.8            57.1
#
# [522192 rows x 7 columns]

# %%
g = lambda dftemp : dftemp['Location'].pop(0)
dftemp['Location'] = dftemp.apply(g, axis=1)
dftemp.reset_index()
dftemp
# Out:
#         Location ID  Location    Date  Value  Rank  \
# 0               101  Alabama   189501   37.7    36
# 1               101  Alabama   189502   32.8     3
# 2               101  Alabama   189503   50.3    53
# 3               101  Alabama   189504   61.2    88
# 4               101  Alabama   189505   66.8    42
# ...             ...       ...     ...    ...   ...
# 522187         4810  Wyoming   202102   18.5    30
# 522188         4810  Wyoming   202103   30.9    85
# 522189         4810  Wyoming   202104   37.0    51
# 522190         4810  Wyoming   202105   48.3    70
# 522191         4810  Wyoming   202106   63.9   126
#
#         Anomaly (1901-2000 base period)  1901-2000 Mean
# 0                                  -2.4            40.1
# 1                                 -10.3            43.1
# 2                                  -0.6            50.9
# 3                                   1.4            59.8
# 4                                  -1.2            68.0
# ...                                 ...             ...
# 522187                             -3.2            21.7
# 522188                              2.9            28.0
# 522189                             -0.5            37.5
# 522190                              0.9            47.4
# 522191                              6.8            57.1
#
# [522192 rows x 7 columns]

# %%
dftemp = dftemp.drop(columns=['Location ID','Rank','Anomaly (1901-2000 base period)','1901-2000 Mean'])
dftemp
# Out:
#         Location    Date  Value
# 0       Alabama   189501   37.7
# 1       Alabama   189502   32.8
# 2       Alabama   189503   50.3
# 3       Alabama   189504   61.2
# 4       Alabama   189505   66.8
# ...          ...     ...    ...
# 522187  Wyoming   202102   18.5
# 522188  Wyoming   202103   30.9
# 522189  Wyoming   202104   37.0
# 522190  Wyoming   202105   48.3
# 522191  Wyoming   202106   63.9
#
# [522192 rows x 3 columns]

# %%
dftemp['Location'] = dftemp['Location'].str.rstrip()

# %%
dftemp['Celsius'] = (dftemp['Value']-32)*5/9
dftemp['Celsius'] = dftemp['Celsius'].round(1)
dftemp = dftemp.drop(columns=['Value'])
dftemp
# Out:
#        Location    Date  Celsius
# 0       Alabama  189501      3.2
# 1       Alabama  189502      0.4
# 2       Alabama  189503     10.2
# 3       Alabama  189504     16.2
# 4       Alabama  189505     19.3
# ...         ...     ...      ...
# 522187  Wyoming  202102     -7.5
# 522188  Wyoming  202103     -0.6
# 522189  Wyoming  202104      2.8
# 522190  Wyoming  202105      9.1
# 522191  Wyoming  202106     17.7
#
# [522192 rows x 3 columns]

# %%
dftemp = dftemp.drop(dftemp[dftemp['Date'] % 10 != 7].index)
dftemp
# Out:
#        Location    Date  Celsius
# 6       Alabama  189507     25.0
# 18      Alabama  189607     26.6
# 30      Alabama  189707     26.8
# 42      Alabama  189807     26.6
# 54      Alabama  189907     26.6
# ...         ...     ...      ...
# 522132  Wyoming  201607     18.9
# 522144  Wyoming  201707     19.8
# 522156  Wyoming  201807     19.6
# 522168  Wyoming  201907     19.1
# 522180  Wyoming  202007     19.0
#
# [43344 rows x 3 columns]

# %%
dftemp['Date'] = dftemp['Date']//100
dftemp['Date'] = dftemp['Date'].astype(int)
dftemp
# Out:
#        Location  Date  Celsius
# 6       Alabama  1895     25.0
# 18      Alabama  1896     26.6
# 30      Alabama  1897     26.8
# 42      Alabama  1898     26.6
# 54      Alabama  1899     26.6
# ...         ...   ...      ...
# 522132  Wyoming  2016     18.9
# 522144  Wyoming  2017     19.8
# 522156  Wyoming  2018     19.6
# 522168  Wyoming  2019     19.1
# 522180  Wyoming  2020     19.0
#
# [43344 rows x 3 columns]

# %%
dftemp = dftemp.drop(dftemp[dftemp.Date > 2018].index)
dftemp = dftemp.drop(dftemp[dftemp['Date'] < 1992].index)
dftemp = dftemp.reset_index(drop = True)
dftemp = dftemp.reset_index(drop = False)
dftemp
# Out:
#       index Location  Date  Celsius
# 0         0  Alabama  1992     25.6
# 1         1  Alabama  1993     27.6
# 2         2  Alabama  1994     24.7
# 3         3  Alabama  1995     26.1
# 4         4  Alabama  1996     25.4
# ...     ...      ...   ...      ...
# 9283   9283  Wyoming  2014     18.9
# 9284   9284  Wyoming  2015     17.4
# 9285   9285  Wyoming  2016     18.9
# 9286   9286  Wyoming  2017     19.8
# 9287   9287  Wyoming  2018     19.6
#
# [9288 rows x 4 columns]

# %%
dffinal = df2.groupby(['Date','Location']).size()
dffinal = dffinal.to_frame()
dffinal.reset_index(inplace = True)
dffinal = dffinal.drop(dffinal[dffinal.Location == 'Alaska'].index)
dffinal = dffinal.drop(dffinal[dffinal.Location == 'Hawaii'].index)
dffinal = dffinal.sort_values(by=['Location','Date'])
dffinal = dffinal.rename(columns={0: '# of Fires'})
dffinal = dffinal.reset_index(drop=True)
dffinal = dffinal.reset_index(drop=False)

# %%
d1=dffinal
d1 = d1.drop(columns=['index'])
d1['Date']=d1['Date'].values.astype(str)
d1['Location']=d1['Location'].values.astype(str)
d1['id'] = d1['Date'].str.cat(d1['Location'],sep='-')
d1
# Out:
#       Date Location  # of Fires            id
# 0     1992  Alabama           2  1992-Alabama
# 1     1993  Alabama           7  1993-Alabama
# 2     1994  Alabama          11  1994-Alabama
# 3     1995  Alabama          55  1995-Alabama
# 4     1996  Alabama          32  1996-Alabama
# ...    ...      ...         ...           ...
# 1058  2014  Wyoming          88  2014-Wyoming
# 1059  2015  Wyoming         141  2015-Wyoming
# 1060  2016  Wyoming         182  2016-Wyoming
# 1061  2017  Wyoming         263  2017-Wyoming
# 1062  2018  Wyoming         193  2018-Wyoming
#
# [1063 rows x 4 columns]

# %%
dftemp12 = dftemp
dftemp12 = dftemp12.drop(columns=['index'])
dftemp12['Date']=dftemp12['Date'].values.astype(str)
dftemp12['Location']=dftemp12['Location'].values.astype(str)
dftemp12['id'] = dftemp12['Date'].str.cat(dftemp12['Location'],sep='-')
dftemp100 = dftemp12.drop(columns=['Date','Location'])
dftemp100
# Out:
#       Celsius            id
# 0        25.6  1992-Alabama
# 1        27.6  1993-Alabama
# 2        24.7  1994-Alabama
# 3        26.1  1995-Alabama
# 4        25.4  1996-Alabama
# ...       ...           ...
# 9283     18.9  2014-Wyoming
# 9284     17.4  2015-Wyoming
# 9285     18.9  2016-Wyoming
# 9286     19.8  2017-Wyoming
# 9287     19.6  2018-Wyoming
#
# [9288 rows x 2 columns]

# %%
result = pd.merge(d1,dftemp100,how='right',on='id')
result = result.drop(columns=['id'])
result
# Out:
#       Date Location  # of Fires  Celsius
# 0     1992  Alabama         2.0     25.6
# 1     1993  Alabama         7.0     27.6
# 2     1994  Alabama        11.0     24.7
# 3     1995  Alabama        55.0     26.1
# 4     1996  Alabama        32.0     25.4
# ...    ...      ...         ...      ...
# 9283  2014  Wyoming        88.0     18.9
# 9284  2015  Wyoming       141.0     17.4
# 9285  2016  Wyoming       182.0     18.9
# 9286  2017  Wyoming       263.0     19.8
# 9287  2018  Wyoming       193.0     19.6
#
# [9288 rows x 4 columns]

# %%
dffinal1 = dffinal.drop(dffinal[dffinal.index > 255].index)
dffinal2 = dffinal.drop(dffinal[(dffinal.index <= 255)].index)
dffinal2 = dffinal2.drop(dffinal2[(dffinal2.index > 539)].index)
dffinal3 = dffinal.drop(dffinal[(dffinal.index <= 539)].index)
dffinal3 = dffinal3.drop(dffinal3[(dffinal3.index > 820)].index)
dffinal4 = dffinal.drop(dffinal[dffinal.index <= 820].index)

dftempfinal1 = dftemp.drop(dftemp[dftemp.index > 2537].index)
dftempfinal2 = dftemp.drop(dftemp[(dftemp.index <= 2537)].index)
dftempfinal2 = dftempfinal2.drop(dftempfinal2[(dftempfinal2.index > 4859)].index)
dftempfinal3 = dftemp.drop(dftemp[(dftemp.index <= 4859)].index)
dftempfinal3 = dftempfinal3.drop(dftempfinal3[(dftempfinal3.index > 7289)].index)
dftempfinal4 = dftemp.drop(dftemp[dftemp.index <= 7289].index)

# %%
size = (12, 12)
fig, ax = plt.subplots(figsize=size)
sns.lineplot(x='Date', y='Celsius', data= dftempfinal1, hue = 'Location', style = 'Location', ci=None)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Celsius'>

# %%
size = (12, 12)
fig, ax = plt.subplots(figsize=size)
sns.lineplot(x='Date', y='Celsius', data= dftempfinal2, hue = 'Location', style = 'Location', ci=None)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Celsius'>

# %%
size = (12, 12)
fig, ax = plt.subplots(figsize=size)
sns.lineplot(x='Date', y='Celsius', data= dftempfinal3, hue = 'Location', style = 'Location', ci=None)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Celsius'>

# %%
size = (12, 12)
fig, ax = plt.subplots(figsize=size)
sns.lineplot(x='Date', y='Celsius', data= dftempfinal4, hue = 'Location', style = 'Location', ci=None)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Celsius'>

# %%
size = (15, 15)
fig, ax = plt.subplots(figsize=size)
sns.barplot(x='Date', y='# of Fires', data = dffinal1, hue = 'Location')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='# of Fires'>

# %%
size = (15, 15)
fig, ax = plt.subplots(figsize=size)
sns.barplot(x='Date', y='# of Fires', data = dffinal2, hue = 'Location')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='# of Fires'>

# %%
size = (15, 15)
fig, ax = plt.subplots(figsize=size)
sns.barplot(x='Date', y='# of Fires', data = dffinal3, hue = 'Location')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='# of Fires'>

# %%
size = (15, 15)
fig, ax = plt.subplots(figsize=size)
sns.barplot(x='Date', y='# of Fires', data = dffinal4, hue = 'Location')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='# of Fires'>
